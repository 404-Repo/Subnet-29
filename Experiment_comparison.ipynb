# %%
import os
from src.func import RewardModel

# %%
validator = RewardModel(metric='cosine', aggregation='mean')

# %%
path = "assets/references"
ext  = ".jpg"
refs = []
for file in os.listdir(path):
    if file.endswith(ext):
        refs.append(os.path.join(path, file))

# %%
cat_poem = Symbol('cat').query('a poem of a cat')
cat_poem_sentence = Symbol('Orange tabby cat lying down, looking at camera.').query('a poem of a cat')
dog_poem = Symbol('dog').query('a poem of a dog')

# %%
cat_poem
# Out:
# <class symai.symbol.Symbol at 0x7f9daa5208b0>(value=Silent paws tread softly through the night,
# Whiskers trembling, eyes gleaming bright.
# Graceful frame with fur so sleek,
# A velvet touch, and a gentle cheek.
#
# Ears that twitch at the faintest sound,
# Huntress spirit, forever unbound.
# In moonlit whispers and starry gaze,
# This feline beauty commands amaze.
#
# With a languid stretch and a yawning sigh,
# She reigns her kingdom beneath the sky.
# Through alleys and gardens, she roams free,
# A sight of elegance, this cat to see.
#
# So here's to the wanderer, the mysterious pet,
# A creature of comfort we'll never forget.
# With each tender purr and each playful pat,
# We find our hearts stolen by the loving cat.)

# %%
cat_poem_sentence
# Out:
# <class symai.symbol.Symbol at 0x7f9daa4f7b50>(value=Gaze fixed, eyes gleaming bright,
# Orange fur in soft sunlight.
# A tabby cat with gentle mien,
# In lazy pose, a regal queen.
#
# Whiskers twitch with slightest sound,
# In feline world, she's unbound.
# Lying down, yet poised in grace,
# A picture of calm in this quiet space.
#
# She looks upon the lens, aware
# With a deep and thoughtful stare.
# This orange tabby, fur adorned,
# In her presence, hearts are warmed.
#
# Embodying the spirit of a cat,
# A tranquil force where she sat.
# Through the camera, she connects,
# A purring poem of introspects.)

# %%
dog_poem
# Out:
# <class symai.symbol.Symbol at 0x7f9daa4c0250>(value=With a wagging tail and a playful bark,
# A faithful companion from dawn to dark.
# A dog, a friend, with a heart so pure,
# Brings joy and comfort, that's for sure.
#
# With ears perked up and eyes full of glee,
# A canine friend, as loyal as can be.
# From the rustle of leaves to the chirping of a frog,
# Life's simple pleasures enjoyed by the dog.
#
# Through fields and parks, it loves to roam,
# Yet always finds its way back home.
# A cold nose nudge, a gentle paw,
# In every gesture, love we saw.
#
# Protective, kind, and full of love,
# A precious gift from heaven above.
# This creature, small or tall or big,
# Dances through life, a happy jig.
#
# So here's to the dog, with a spirit so free,
# Forever in our hearts, it will always be.
# With boundless energy and a spirit that's strong,
# In the land of tail wags, that's where you belong.)

# %%
scores = validator(images=['assets/img/cat.jpeg',
                           'assets/img/steam_deck.jpg',
                           'assets/img/dog.jpeg'],
                   references=refs)

# %%
scores.value
# Out:
# array([[0.3521191 , 0.31240105, 0.33547985]])

# %%
scores.metadata.scores
# Out:
# [0.8997060425749851, 0.7800243517350027, 0.8512984770250712]

# %%
scores.metadata.similarities
# Out:
# {'assets/img/cat.jpeg': <class symai.symbol.Symbol at 0x7f9d9920eec0>(value=[0.8709148144799788, 0.9056435345814491, 0.9163570439425367, 0.9211001503089616, 0.8845146695619989]),
#  'assets/img/steam_deck.jpg': <class symai.symbol.Symbol at 0x7f9d9920f010>(value=[0.7935138126447256, 0.7838255700137767, 0.7741805182230037, 0.7810501035465431, 0.7675517542469641]),
.005110324360430241, -0.0009389257756993175, -0.015138372778892517, -0.010785609483718872, 0.027272183448076248, -0.007845246233046055, 0.0028729524929076433, 0.034488268196582794, -0.006115055177360773, 0.004808584228157997, 0.000549311691429466, 0.011543169617652893, 0.004442643839865923, 0.0071454658173024654, 0.0003727615694515407, 0.004352763760834932, -0.0008546632016077638, 0.017462413758039474, -0.029429305344820023, -0.0090907271951437, 0.008538607507944107, 0.022495698183774948, 0.024691341444849968, -0.017655014991760254, 0.022701138630509377, -0.006304445210844278, -0.014547731727361679, 0.023497220128774643, 0.0334867462515831, 0.003266177838668227, 0.013045450672507286, -0.007325225975364447, -0.0030607376247644424, 0.015228252857923508, 0.029429305344820023, -0.0036529831122606993, -0.03885387256741524, -0.024331821128726006, 0.011613789945840836, -0.0027557872235774994, 0.0012077635619789362, -0.017385374754667282, -0.009835448116064072, 0.00874404702335596, -0.023368818685412407, 0.036208830773830414, -0.009122828021645546, -0.015356652438640594, 0.03461666777729988, 0.01018212828785181, -0.034488268196582794, -0.02315053902566433, 0.015035652555525303, 0.0238952599465847, -0.005745904985815287, 0.016473732888698578, -0.00018497640849091113, 0.009495187550783157, 0.0026883771643042564, 0.03531002998352051, -0.03287042677402496, -0.01180639024823904, 0.0140983322635293, -0.012223689816892147, -0.002258236985653639, 0.0017205614130944014, 0.01276297029107809, 0.00387447327375412, 0.014650451950728893, 0.011883430182933807, 0.010406828485429287, -0.042320676147937775, 0.01655077375471592, -0.009578648023307323, 0.025513101369142532, 0.004789324011653662, -0.028735945001244545, 0.011247849091887474, 0.03597771003842354, -0.032947465777397156, -0.008108466863632202, -0.001609013881534338, 0.03222842514514923, -0.00710052577778697, 0.002457257127389312, 0.0014790087006986141, -0.012640990316867828, -0.0005304529331624508, -0.012403449974954128, 0.015305292792618275, -0.0008410207228735089, 0.00475722411647439, -0.002654672134667635, -0.02966042421758175, 0.04419531673192978, -0.018245656043291092, 0.027374902740120888, 0.020056096836924553, 0.0025519521441310644, -0.005213044583797455, 0.002693192334845662, 0.012076030485332012, 0.0210319384932518, 0.02009461633861065, -0.0024203420616686344, -0.006115055177360773, -0.003547053085640073, -0.0105159692466259, 0.019388416782021523, -0.026989702135324478, 0.020133137702941895, 0.001675621373578906, 0.013700291514396667, -0. ...

# %%
import numpy as np
from symai import Symbol
from symai.components import Metric

a = Symbol(np.array([1, 2, 3]))
b = Symbol(np.array([-1, -2, -3]))

res = a.similarity(b, metric='cosine')
print(res)
# Out:
# -0.9999999992857143

# %%
metric = Metric(normalize=True)

# %%
metric(a)
# Out:
# <class symai.symbol.Symbol at 0x7f9bf0bbf1f0>(value=[[0.09003057 0.24472847 0.66524096]])

# %%
a = Symbol('cat').embed()
b = Symbol('console').embed()
c = Symbol('dog').embed()
d = Symbol('children').embed()
e = Symbol('banana').embed()

# %%
print(a.similarity(b, metric='cosine'))
print(a.similarity(c, metric='cosine'))
# Out:
# 0.814302461917929
# 0.8636845304569604

# %%
cat_poem_emb = cat_poem.embed()
cat_poem_sentence_emb = cat_poem_sentence.embed()
dog_poem_emb = dog_poem.embed()

# %%
print(a.similarity(cat_poem_emb, metric='cosine'))
print(a.similarity(cat_poem_sentence_emb, metric='cosine'))
print(a.similarity(dog_poem_emb, metric='cosine'))
# Out:
# 0.8099915340169132
# 0.8051927881872328
# 0.7508644215680985

# %%
print(cat_poem_emb.similarity(dog_poem_emb, metric='cosine'))
print(cat_poem_sentence_emb.similarity(dog_poem_emb, metric='cosine'))
# Out:
# 0.8572713023065729
# 0.8190841869731871

# %%
for m in ['cosine', 'product', 'manhattan', 'euclidean', 'minkowski', 'jaccard']:
    print('Metric', m)
    print(a.similarity(b, metric=m))
    print(a.similarity(c, metric=m))
    print(b.similarity(c, metric=m))
    print('--------')
# Out:
# Metric cosine
# 0.8895274204527135
# 0.77693653092672
# 0.7595380175010066
# --------
# Metric product
# 0.0005791193599868609
# 0.0005058180188032318
# 0.0004944909084462751
# --------
# Metric manhattan
# 0.009409904236638997
# 0.013493195730452944
# 0.0140722109366857
# --------
# Metric euclidean
# 0.00030602083059494655
# 0.0004348485070026227
# 0.00045148880890700984
# --------
# Metric minkowski
# 0.00010709075780496943
# 0.00015067756227272878
# 0.00015647761412506474
# --------
# Metric jaccard
# -1.384014867068355
# -1.2607028427333318
# -1.2418414157559268
# --------

# %%
print(a[0], b[0], c[0], d[0], e[0])
# Out:
# [-0.0008913888013921678, 0.015325159765779972, -0.010945581831037998, -0.019738376140594482, -0.01629391498863697, 0.03393332287669182, -0.011571235954761505, -0.005247420631349087, -0.00027309294091537595, -0.006222902797162533, 0.007400209084153175, 0.024905066937208176, -0.010649573057889938, 0.003908655606210232, 0.002487479243427515, 0.025752726942300797, 0.008981162682175636, -0.014921512454748154, 0.014060396701097488, -0.005943713244050741, -0.015876810997724533, 0.006081626284867525, -0.017545223236083984, -0.019065629690885544, -0.009297353215515614, -0.01899835467338562, 0.015876810997724533, -0.02029002644121647, 0.0014960195403546095, -0.029412467032670975, 0.008463148027658463, -0.01480041816830635, -0.028362981975078583, -0.025671998038887978, -0.018419792875647545, -0.012667812407016754, -0.007702944800257683, -0.021231871098279953, 0.014437134377658367, -0.021998802199959755, 0.021500971168279648, 0.008247869089245796, 0.013105097226798534, 0.009465539827942848, -0.033637311309576035, -0.0019139631185680628, 0.0045847659930586815, -0.008907160721719265, -0.0023310657124966383, 0.032991476356983185, 0.01755867712199688, 0.010266107507050037, -0.01489460188895464, -0.015849901363253593, 0.008678426966071129, 0.018581252545118332, -0.006613095756620169, -0.0014548137551173568, 0.0004194152425043285, -0.011847062036395073, -0.006777918431907892, -0.011302136816084385, -0.029251007363200188, -0.0038279262371361256, -0.01101958379149437, -0.01742412894964218, -0.015311704948544502, 0.011793241836130619, 0.009129166603088379, -0.00949917733669281, 0.02970847487449646, 0.007205112371593714, 0.0080460449680686, -0.012304529547691345, 0.03498280420899391, 0.011914336122572422, -0.004187845624983311, 0.003286365419626236, -0.0034915530122816563, -0.0068889218382537365, 0.02787860482931137, -0.022335175424814224, -0.011981611140072346, 0.019267452880740166, 0.026021825149655342, -0.010467931628227234, 0.007400209084153175, 0.01820451393723488, -0.028685901314020157, -0.0034326878376305103, -0.0027363954577594995, 0.02711167372763157, -0.00799222569912672, 0.0017962325364351273, -0.0012613992439582944, 0.017706681042909622, -0.004816863220185041, 0.026936760172247887, -0.002492524916306138, -0.018244879320263863, -0.013380923308432102, 0.007063835859298706, -0.00844296533614397, -0.008402600884437561, -0.011988338083028793, -0.02206607721745968, 0.006105172447860241, 0.00012319665984250605, 0.008503512479364872, 0.0033855955116450787, -0.014773507602512836, 0.03842726722359657, 0.007696217391639948, -0.0229137372225523, -0.005745253060013056, 0.005570339038968086, -0.0007177361403591931, -0.028793539851903915, -0.0015876811230555177, -0.01481387298554182, 0.005930258426815271, 0.032883837819099426, 0.013071459718048573, -0.0026354833971709013, 0.018809985369443893, 0.00921662338078022, -0.007837493903934956, -0.0213664211332798, -0.017989234998822212, -0.014221856370568275, 0.04321721941232681, 0.007319479249417782, 0.025550903752446175, -0.015446254052221775, -0.018621616065502167, 0.02847062237560749, -0.0022940647322684526, 0.01938854716718197, -0.01642846316099167, -0.013703841716051102, 0.0014321085764095187, 0.022456269711256027, -0.007043653167784214, -0.011705785058438778, 0.0014514500508084893, 0.009674090892076492, 0.016563013195991516, -0.0038279262371361256, -0.012109432369470596, -0.020935863256454468, 0.0012201935751363635, 0.013380923308432102, 0.020411120727658272, 0.0006302791298367083, 0.0006672801682725549, 0.02785169519484043, 0.01219016220420599, 0.02471669763326645, -0.03729705139994621, -0.0028171250596642494, -0.019402002915740013, -0.0057856179773807526, 0.0189176257699728, -0.011423231102526188, 0.01482732780277729, 0.021500971168279648, 0.020007474347949028, 0.02849753201007843, 0.012721631675958633, 0.004726042505353689, 0.0027178949676454067, 0.01340110506862402, -0.007184930145740509, 0.01103303860872984, -0.006976378615945578, 0.01632082462310791, 0.005055688321590424, 0.004261847585439682, - ...

# %%
import matplotlib.pyplot as plt

# %%
a = Symbol([1, 1, 1, 2, 2, 1])
b = Symbol([1, 1, 1, 2, 1, 1])
c = Symbol([1, 1, 1, 2, 1, 2])
d = Symbol([1, 1, 1, 1, 1, 1])
e = Symbol([1, 1, 1, 1, 2, 1])

# %%
a_v = np.vstack([np.array(a.value),
                 np.array(a.value),
                 np.array(a.value),
                 np.array(a.value)])
b_v = np.vstack([np.array(b.value),
                 np.array(c.value),
                 np.array(d.value),
                 np.array(e.value)])

# %%
a_v = np.array(a.value)
b_v = np.array(b.value)
c_v = np.array(c.value)
d_v = np.array(d.value)
e_v = np.array(e.value)

# %%
aa_out = (a_v.T @ a_v)
ab_out = (a_v.T @ b_v)
ac_out = (a_v.T @ c_v)
ad_out = (a_v.T @ d_v)

# %%
plt.imshow(ab_out, cmap='jet')

# %%
plt.hist(ab_out.flatten(), bins=10)
# Out:
# (array([2.000000e+00, 5.590000e+02, 2.358728e+06, 4.000000e+00,
#         2.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 1.000000e+00]),
#  array([-0.12699152, -0.06877986, -0.01056821,  0.04764345,  0.1058551 ,
#          0.16406675,  0.22227841,  0.28049006,  0.33870172,  0.39691337,
#          0.45512502]),
#  <BarContainer object of 10 artists>)

# %%
aaU, aaS, aaVh = np.linalg.svd(aa_out)
abU, abS, abVh = np.linalg.svd(ab_out)

# %%
plt.plot(aaS[:10])
plt.yscale("log")

# %%
plt.plot(abS[:10])
plt.yscale("log")

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=a_v.shape[1])
pca.fit(aa_out)
# Out:
# PCA(n_components=1536)

# %%
pca.singular_values_
# Out:
# array([9.99536297e-01, 2.65922727e-15, 2.56258450e-15, ...,
#        4.38366184e-17, 3.89745555e-17, 1.48033238e-17])
